# %%
import os
import tensorflow as tf

# %%
print(tf.config.experimental.list_physical_devices('GPU'))
print(tf.__version__)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2.6.0

# %%
# !pip3 install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.5.2-cp39-cp39-win_amd64.whl (7.2 MB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.33.3-py3-none-any.whl (930 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\simon\anaconda3\envs\tf-gpu\lib\site-packages (from matplotlib) (1.21.5)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.2-cp39-cp39-win_amd64.whl (55 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\simon\anaconda3\envs\tf-gpu\lib\site-packages (from matplotlib) (21.3)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\simon\anaconda3\envs\tf-gpu\lib\site-packages (from matplotlib) (2.8.2)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.1.0-cp39-cp39-win_amd64.whl (3.3 MB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\simon\anaconda3\envs\tf-gpu\lib\site-packages (from matplotlib) (3.0.8)
# Requirement already satisfied: six>=1.5 in c:\users\simon\anaconda3\envs\tf-gpu\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.33.3 kiwisolver-1.4.2 matplotlib-3.5.2 pillow-9.1.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout
from tensorflow.keras.layers import GlobalMaxPooling2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model

# %%
# load data set
cifar10 = tf.keras.datasets.cifar10

# split data for testing / training
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)

# %%
# normalize pixel values between 0 and 1
x_train = x_train / 255.0
x_test = x_test / 255.0

# flatten label values
y_train = y_train.flatten()
y_test = y_test.flatten()

# %%
# visualize images
fig, ax = plt.subplots(5, 5, dpi=100)
k = 0
for i in range(5):
    for j in range(5):
        ax[i][j].imshow(x_train[k], aspect='auto')
        ax[i][j].set_xticks([])
        ax[i][j].set_yticks([])
        k += 1
plt.show()

# %%
# number of classes
K = len(set(y_train))
print("number of classes:", K)
# Out:
# number of classes: 10

# %%
i = Input(shape=x_train[0].shape)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
 
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
 
x = Flatten()(x)
x = Dropout(0.2)(x)
 
# Hidden layer
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
 
# last hidden layer i.e.. output layer
x = Dense(K, activation='softmax')(x)
 
model = Model(i, x)
 
# model description
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 2,397,226
# Trainable params: 2,396,330
# Non-trainable params: 896
# _________________________________________________________________

# %%
# Compile
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Fit
r = model.fit(
    x_train, y_train, 
    validation_data=(x_test, y_test), 
    epochs=50)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 14s 5ms/step - loss: 1.2921 - accuracy: 0.5532 - val_loss: 1.0819 - val_accuracy: 0.6328
# Epoch 2/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8392 - accuracy: 0.7097 - val_loss: 0.7636 - val_accuracy: 0.7429
# Epoch 3/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6813 - accuracy: 0.7671 - val_loss: 0.7873 - val_accuracy: 0.7311
# Epoch 4/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5767 - accuracy: 0.8008 - val_loss: 0.7139 - val_accuracy: 0.7603
# Epoch 5/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4933 - accuracy: 0.8310 - val_loss: 0.6408 - val_accuracy: 0.7890
# Epoch 6/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4248 - accuracy: 0.8543 - val_loss: 0.6582 - val_accuracy: 0.7916
# Epoch 7/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.3556 - accuracy: 0.8766 - val_loss: 0.6285 - val_accuracy: 0.8069
# Epoch 8/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.3034 - accuracy: 0.8950 - val_loss: 0.6282 - val_accuracy: 0.8171
# Epoch 9/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2587 - accuracy: 0.9106 - val_loss: 0.6093 - val_accuracy: 0.8266
# Epoch 10/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2202 - accuracy: 0.9236 - val_loss: 0.6244 - val_accuracy: 0.8251
# Epoch 11/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.2000 - accuracy: 0.9314 - val_loss: 0.7089 - val_accuracy: 0.8217
# Epoch 12/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1728 - accuracy: 0.9409 - val_loss: 0.6879 - val_accuracy: 0.8195
# Epoch 13/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1569 - accuracy: 0.9470 - val_loss: 0.7344 - val_accuracy: 0.8223
# Epoch 14/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1438 - accuracy: 0.9511 - val_loss: 0.7425 - val_accuracy: 0.8154
# Epoch 15/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1403 - accuracy: 0.9524 - val_loss: 0.7097 - val_accuracy: 0.8252
# Epoch 16/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1247 - accuracy: 0.9578 - val_loss: 0.6943 - val_accuracy: 0.8336
# Epoch 17/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1123 - accuracy: 0.9623 - val_loss: 0.7594 - val_accuracy: 0.8244
# Epoch 18/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1114 - accuracy: 0.9632 - val_loss: 0.7058 - val_accuracy: 0.8364
# Epoch 19/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1041 - accuracy: 0.9666 - val_loss: 0.7207 - val_accuracy: 0.8361
# Epoch 20/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0973 - accuracy: 0.9688 - val_loss: 0.7967 - val_accuracy: 0.8284
# Epoch 21/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0919 - accuracy: 0.9695 - val_loss: 0.7693 - val_accuracy: 0.8344
# Epoch 22/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0867 - accuracy: 0.9714 - val_loss: 0.7342 - val_accuracy: 0.8338
# Epoch 23/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0867 - accuracy: 0.9711 - val_loss: 0.7476 - val_accuracy: 0.8287
# Epoch 24/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0811 - accuracy: 0.9732 - val_loss: 0.8052 - val_accuracy: 0.8303
# Epoch 25/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0814 - accuracy: 0.9731 - val_loss: 0.7617 - val_accuracy: 0.8354
# Epoch 26/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0724 - accuracy: 0.9758 - val_loss: 0.7411 - val_accuracy: 0.8343
# Epoch 27/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0743 - accuracy: 0.9753 - val_loss: 0.7966 - val_accuracy: 0.8406
# Epoch 28/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0670 - accuracy: 0.9784 - val_loss: 0.8414 - val_accuracy: 0.8260
# Epoch 29/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0628 - accuracy: 0.9787 - val_loss: 0.8252 - val_accuracy: 0.8390
# Epoch 30/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0675 - accuracy: 0.9774 - val_loss: 0.9318 - val_accuracy: 0.8261
# Epoch 31/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0569 - accuracy: 0.9807 - val_loss: 0.8978 - val_accuracy: 0.8273
# Epoch 32/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0600 - accuracy: 0.9813 - val_loss: 0.8519 - val_accuracy: 0.8367
# Epoch 33/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0570 - accuracy: 0.9813 - val_loss: 0.8113 - val_accuracy: 0.8264
# Epoch 34/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.0548 - accuracy: 0.9819 - val_loss: 0.9571 - val_accuracy: 0.8340
# Epoch 35/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0595 - accuracy: 0.9810 - val_loss: 0.7928 - val_accuracy: 0.8388
# Epoch 36/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0540 - accuracy: 0.9831 - val_loss: 0.8661 - val_accuracy: 0.8401
# Epoch 37/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0514 - accuracy: 0.9833 - val_loss: 0.8410 - val_accuracy: 0.8402
# Epoch 38/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0527 - accuracy: 0.9833 - val_loss: 0.9627 - val_accuracy: 0.8237
# Epoch 39/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0518 - accuracy: 0.9833 - val_loss: 0.7994 - val_accuracy: 0.8427
# Epoch 40/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0483 - accuracy: 0.9847 - val_loss: 0.8946 - val_accuracy: 0.8298
# Epoch 41/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0493 - accuracy: 0.9838 - val_loss: 0.8778 - val_accuracy: 0.8380
# Epoch 42/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0473 - accuracy: 0.9850 - val_loss: 0.8111 - val_accuracy: 0.8440
# Epoch 43/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0436 - accuracy: 0.9853 - val_loss: 0.9183 - val_accuracy: 0.8393
# Epoch 44/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0469 - accuracy: 0.9845 - val_loss: 0.8401 - val_accuracy: 0.8422
# Epoch 45/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0475 - accuracy: 0.9850 - val_loss: 0.8385 - val_accuracy: 0.8390
# Epoch 46/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0405 - accuracy: 0.9866 - val_loss: 0.9076 - val_accuracy: 0.8341
# Epoch 47/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0462 - accuracy: 0.9850 - val_loss: 0.9704 - val_accuracy: 0.8355
# Epoch 48/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0417 - accuracy: 0.9867 - val_loss: 0.8984 - val_accuracy: 0.8459
# Epoch 49/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0411 - accuracy: 0.9872 - val_loss: 0.8433 - val_accuracy: 0.8431
# Epoch 50/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0407 - accuracy: 0.9870 - val_loss: 0.8782 - val_accuracy: 0.8449

# %%
# Fit with data augmentation
# Note: if you run this AFTER calling
# the previous model.fit()
# it will CONTINUE training where it left off
batch_size = 32
data_generator = tf.keras.preprocessing.image.ImageDataGenerator(
  width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
 
train_generator = data_generator.flow(x_train, y_train, batch_size)
steps_per_epoch = x_train.shape[0] // batch_size
 
r = model.fit(train_generator, validation_data=(x_test, y_test),
              steps_per_epoch=steps_per_epoch, epochs=50)
# Out:
# Epoch 1/50
# 1562/1562 [==============================] - 13s 8ms/step - loss: 0.5462 - accuracy: 0.8249 - val_loss: 0.5168 - val_accuracy: 0.8330
# Epoch 2/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.4318 - accuracy: 0.8596 - val_loss: 0.4548 - val_accuracy: 0.8522
# Epoch 3/50
# 1562/1562 [==============================] - 11s 7ms/step - loss: 0.4089 - accuracy: 0.8655 - val_loss: 0.4876 - val_accuracy: 0.8477
# Epoch 4/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.3852 - accuracy: 0.8714 - val_loss: 0.4537 - val_accuracy: 0.8519
# Epoch 5/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.3655 - accuracy: 0.8768 - val_loss: 0.4392 - val_accuracy: 0.8575
# Epoch 6/50
# 1562/1562 [==============================] - 11s 7ms/step - loss: 0.3482 - accuracy: 0.8819 - val_loss: 0.4494 - val_accuracy: 0.8561
# Epoch 7/50
# 1562/1562 [==============================] - 11s 7ms/step - loss: 0.3336 - accuracy: 0.8868 - val_loss: 0.4733 - val_accuracy: 0.8480
# Epoch 8/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.3205 - accuracy: 0.8919 - val_loss: 0.4876 - val_accuracy: 0.8476
# Epoch 9/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.3112 - accuracy: 0.8938 - val_loss: 0.4046 - val_accuracy: 0.8710
# Epoch 10/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.3049 - accuracy: 0.8977 - val_loss: 0.4500 - val_accuracy: 0.8574
# Epoch 11/50
# 1562/1562 [==============================] - 12s 8ms/step - loss: 0.2990 - accuracy: 0.8996 - val_loss: 0.4485 - val_accuracy: 0.8573
# Epoch 12/50
# 1562/1562 [==============================] - 12s 8ms/step - loss: 0.2863 - accuracy: 0.9034 - val_loss: 0.4688 - val_accuracy: 0.8601
# Epoch 13/50
# 1562/1562 [==============================] - 12s 8ms/step - loss: 0.2881 - accuracy: 0.9027 - val_loss: 0.3859 - val_accuracy: 0.8702
# Epoch 14/50
# 1562/1562 [==============================] - 11s 7ms/step - loss: 0.2724 - accuracy: 0.9080 - val_loss: 0.4005 - val_accuracy: 0.8680
# Epoch 15/50
# 1562/1562 [==============================] - 11s 7ms/step - loss: 0.2736 - accuracy: 0.9073 - val_loss: 0.4352 - val_accuracy: 0.8587
# Epoch 16/50
# 1562/1562 [==============================] - 11s 7ms/step - loss: 0.2618 - accuracy: 0.9123 - val_loss: 0.4011 - val_accuracy: 0.8718
# Epoch 17/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.2590 - accuracy: 0.9135 - val_loss: 0.4484 - val_accuracy: 0.8675
# Epoch 18/50
# 1562/1562 [==============================] - 11s 7ms/step - loss: 0.2535 - accuracy: 0.9142 - val_loss: 0.4480 - val_accuracy: 0.8648
# Epoch 19/50
# 1562/1562 [==============================] - 11s 7ms/step - loss: 0.2494 - accuracy: 0.9167 - val_loss: 0.4516 - val_accuracy: 0.8672
# Epoch 20/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.2443 - accuracy: 0.9166 - val_loss: 0.4315 - val_accuracy: 0.8665
# Epoch 21/50
# 1562/1562 [==============================] - 12s 8ms/step - loss: 0.2377 - accuracy: 0.9195 - val_loss: 0.4139 - val_accuracy: 0.8683
# Epoch 22/50
# 1562/1562 [==============================] - 12s 8ms/step - loss: 0.2338 - accuracy: 0.9220 - val_loss: 0.3901 - val_accuracy: 0.8811
# Epoch 23/50
# 1562/1562 [==============================] - 12s 8ms/step - loss: 0.2277 - accuracy: 0.9225 - val_loss: 0.3886 - val_accuracy: 0.8814
# Epoch 24/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.2258 - accuracy: 0.9236 - val_loss: 0.4319 - val_accuracy: 0.8725
# Epoch 25/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.2161 - accuracy: 0.9265 - val_loss: 0.4045 - val_accuracy: 0.8781
# Epoch 26/50
# 1562/1562 [==============================] - 11s 7ms/step - loss: 0.2183 - accuracy: 0.9253 - val_loss: 0.4206 - val_accuracy: 0.8783
# Epoch 27/50
# 1562/1562 [==============================] - 11s 7ms/step - loss: 0.2168 - accuracy: 0.9248 - val_loss: 0.4056 - val_accuracy: 0.8749
# Epoch 28/50
# 1562/1562 [==============================] - 11s 7ms/step - loss: 0.2098 - accuracy: 0.9287 - val_loss: 0.4191 - val_accuracy: 0.8743
# Epoch 29/50
# 1562/1562 [==============================] - 11s 7ms/step - loss: 0.2089 - accuracy: 0.9277 - val_loss: 0.4124 - val_accuracy: 0.8816
# Epoch 30/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.2068 - accuracy: 0.9290 - val_loss: 0.4107 - val_accuracy: 0.8804
# Epoch 31/50
# 1562/1562 [==============================] - 12s 8ms/step - loss: 0.2061 - accuracy: 0.9295 - val_loss: 0.4225 - val_accuracy: 0.8781
# Epoch 32/50
# 1562/1562 [==============================] - 12s 8ms/step - loss: 0.2010 - accuracy: 0.9313 - val_loss: 0.4504 - val_accuracy: 0.8764
# Epoch 33/50
# 1562/1562 [==============================] - 12s 8ms/step - loss: 0.1986 - accuracy: 0.9342 - val_loss: 0.4075 - val_accuracy: 0.8812
# Epoch 34/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.1946 - accuracy: 0.9329 - val_loss: 0.3820 - val_accuracy: 0.8860
# Epoch 35/50
# 1562/1562 [==============================] - 11s 7ms/step - loss: 0.1944 - accuracy: 0.9333 - val_loss: 0.4549 - val_accuracy: 0.8730
# Epoch 36/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.1882 - accuracy: 0.9356 - val_loss: 0.4358 - val_accuracy: 0.8795
# Epoch 37/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.1856 - accuracy: 0.9383 - val_loss: 0.4354 - val_accuracy: 0.8806
# Epoch 38/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.1871 - accuracy: 0.9372 - val_loss: 0.3893 - val_accuracy: 0.8863
# Epoch 39/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.1806 - accuracy: 0.9395 - val_loss: 0.4664 - val_accuracy: 0.8725
# Epoch 40/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.1790 - accuracy: 0.9399 - val_loss: 0.4067 - val_accuracy: 0.8858
# Epoch 41/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.1827 - accuracy: 0.9385 - val_loss: 0.4093 - val_accuracy: 0.8795
# Epoch 42/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.1762 - accuracy: 0.9408 - val_loss: 0.4207 - val_accuracy: 0.8760
# Epoch 43/50
# 1562/1562 [==============================] - 12s 8ms/step - loss: 0.1741 - accuracy: 0.9409 - val_loss: 0.4242 - val_accuracy: 0.8852
# Epoch 44/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.1723 - accuracy: 0.9420 - val_loss: 0.4085 - val_accuracy: 0.8891
# Epoch 45/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.1692 - accuracy: 0.9421 - val_loss: 0.4043 - val_accuracy: 0.8776
# Epoch 46/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.1725 - accuracy: 0.9420 - val_loss: 0.3961 - val_accuracy: 0.8809
# Epoch 47/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.1692 - accuracy: 0.9432 - val_loss: 0.4599 - val_accuracy: 0.8823
# Epoch 48/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.1722 - accuracy: 0.9404 - val_loss: 0.4040 - val_accuracy: 0.8895
# Epoch 49/50
# 1562/1562 [==============================] - 12s 7ms/step - loss: 0.1668 - accuracy: 0.9439 - val_loss: 0.4099 - val_accuracy: 0.8833
# Epoch 50/50
# 1562/1562 [==============================] - 12s 8ms/step - loss: 0.1675 - accuracy: 0.9431 - val_loss: 0.4250 - val_accuracy: 0.8840

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='acc', color='red')
plt.plot(r.history['val_accuracy'], label='val_acc', color='green')
plt.legend()

# %%
# label mapping
labels = '''airplane automobile bird cat deerdog frog horseship truck'''.split()
 
# select the image from our test dataset
image_number = 10
 
# display the image
plt.imshow(x_test[image_number])
 
# load the image in an array
n = np.array(x_test[image_number])
 
# reshape it
p = n.reshape(1, 32, 32, 3)
 
# pass in the network for prediction and
# save the predicted label
predicted_label = labels[model.predict(p).argmax()]
 
# load the original label
original_label = labels[y_test[image_number]]
 
# display the result
print("Original label is {} and predicted label is {}".format(
    original_label, predicted_label))
# Out:
# Original label is airplane and predicted label is airplane

# %%
# save the model
model.save('cifar10.h5')
